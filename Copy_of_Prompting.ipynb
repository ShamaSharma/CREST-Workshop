# %%
def zero_shot_prompt(prompt_text):
    """Zero-shot prompting: Give the model a prompt without examples."""
    response = generator(prompt_text, max_length=50, num_return_sequences=1)[0]['generated_text']
    return response.strip()

# %%
from transformers import pipeline

# Initialize the generator (you can change the model as needed)
generator = pipeline('text-generation', model='gpt2')  # e.g., GPT-2, GPT-J, GPT-Neo

def few_shot_prompt(prompt_text, examples):
    """Few-shot prompting: Give the model a prompt with a few examples."""
    formatted_prompt = "\n".join([f"{example['input']}\n{example['output']}" for example in examples])
    formatted_prompt += f"\n{prompt_text}"
    response = generator(formatted_prompt, max_length=50, num_return_sequences=1)
    return response[0]['generated_text']
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# Device set to use cpu

# %%
def chain_of_thought_prompt(prompt_text):
    """Chain-of-thought prompting: Ask the model to think step-by-step."""
    cot_prompt = f"{prompt_text} Let's think step by step."
    response = generator(cot_prompt, max_length=100, num_return_sequences=1)[0]['generated_text']
    return response.strip()

# %%
input_sentence = "This movie was fantastic!"

# %%
print("--- Zero-Shot Prompting ---")
zero_shot_response = zero_shot_prompt(f"Classify the sentiment of the following sentence: '{input_sentence}' Sentiment:")
print(f"Input: '{input_sentence}'")
print(f"Response: {zero_shot_response}")
print("-" * 25)
# Out:
# Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# --- Zero-Shot Prompting ---
# Input: 'This movie was fantastic!'
# Response: Classify the sentiment of the following sentence: 'This movie was fantastic!' Sentiment: 'Amazing.'
#
# The original was directed by Stephen Daldry. It premiered at the United States box office on May 2, 1983. It was nominated for a Golden Globe for Best Picture and Best Director for its lead role in the classic 1960s crime movie.
#
# The scene was shot on a dark, deserted stretch of street near the Hollywood Police Station. It is believed that the scene was filmed in the parking lot of the theater. The scene in question is one of several shots that have been shot at the theater.
#
# It was shot on the spot.
#
# The scene in question was shot at the theater in front of a police station.
#
# This is the scene where the police arrive at the scene.
#
# There are rumors that there were two people present. The scene was shot in the parking lot of the theater.
#
# This is the scene that the police arrive at.
#
# This is the scene that the police arrive at.
#
# There are rumors that there were two people present. The scene was shot in the parking lot of the theater.
#
# This is the scene that the police arrive at.
#
# The scene in question is one of several shots that have been shot at the theater.
#
# This is the
# -------------------------

# %%
print("--- Few-Shot Prompting ---")

# Define the input sentence to classify
input_sentence = "The restaurant interior is good."  # You can change this as needed

# Define few-shot examples
few_shot_examples = [
    {"input": "Classify the sentiment of the following sentence: 'The service was terrible.' Sentiment:", "output": "Negative"},
    {"input": "Classify the sentiment of the following sentence: 'I loved the food.' Sentiment:", "output": "Positive"},
    {"input": "Classify the sentiment of the following sentence: 'The staff was polite, and the experience was average.' Sentiment:", "output": "Neutral"}
]

# Call the few-shot prompting function
few_shot_response = few_shot_prompt(f"Classify the sentiment of the following sentence: '{input_sentence}' Sentiment:", few_shot_examples)

# Print the response
print(f"Response: {input_sentence}")
print(f"Response: {few_shot_response}")
print("-" * 25)
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# --- Few-Shot Prompting ---
# Response: The restaurant interior is good.
# Response: Classify the sentiment of the following sentence: 'The service was terrible.' Sentiment:
# Negative
# Classify the sentiment of the following sentence: 'I loved the food.' Sentiment:
# Positive
# Classify the sentiment of the following sentence: 'The staff was polite, and the experience was average.' Sentiment:
# Neutral
# Classify the sentiment of the following sentence: 'The restaurant interior is good.' Sentiment: following sentence: 'It was a good day.' Sentiment:
# Negative
# Classify the sentiment of the following sentence: 'He was so nice.' Sentiment:
# Positive
# The following sentence was sent to a friend: 'I love him.' Sentiment:
# 'He was nice.' Sentiment:
# The following sentence was sent to a friend: 'I love him.' Sentiment:
# Negative
# Positive
# The following sentence was sent to a colleague: 'He is great.' Sentiment:
# The following sentence was sent to a colleague: 'He is nice.' Sentiment:
# Positive
# The following sentence was sent to a colleague: 'He is good.' Sentiment:
# The following sentence was sent to a colleague: 'He is nice.' Sentiment:
# Negative
# The following sentence was sent to a colleague: 'He is nice.' Sentiment:
# The following sentence was sent to a colleague: 'He is nice.' Sentiment:
# The following sentence was sent to a colleague: 'He is nice.' Sentiment:
# The following sentence was sent to a colleague: 'He is nice.' Sentiment:
# The following sentence was sent to a colleague: 'He is nice.' Sentiment
# -------------------------

# %%
print("--- Chain-of-Thought Prompting ---")
cot_response = chain_of_thought_prompt(f"Classify the sentiment of the following sentence: '{input_sentence}' Sentiment:")
print(f"Input: '{input_sentence}'")
print(f"Response: {cot_response}")
print("-" * 25)
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=100) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# --- Chain-of-Thought Prompting ---
# Input: 'The restaurant interior is good.'
# Response: Classify the sentiment of the following sentence: 'The restaurant interior is good.' Sentiment: Let's think step by step.
#
# A restaurant is a place where you are served fresh food. A hot dog? A hot soup? It is a place where you are served fresh food. A special sauce? It is a place where you are served fresh food. A dish? It is a place where you are served fresh food. A drink? It is a place where you are served fresh food. A beverage? It is a place where you are served fresh food. A piece of furniture? It is a place where you are served fresh food.
#
# When you see a restaurant you feel it: that it is a place where you can enjoy your food. When you hear a restaurant say that it is a place where you can enjoy your food, you feel it: food in the mouth. That is the feeling of food in the mouth. It is the feeling of food in the mouth. For us, it is a place where we can enjoy food. For us, it is a place where we can enjoy food.
#
# It is the feeling of food in the mouth. That is the feeling of food in the mouth. For us, it is a place where we can enjoy food. For us, it is a place where we can enjoy food. It is the feeling of food
# -------------------------

# %%
input_sentence_2 = "I love to visit Delhi but it is crowded."

# %%
print("\n--- Zero-Shot Prompting (Second Input) ---")
zero_shot_response_2 = zero_shot_prompt(f"Classify the sentiment of the following sentence: '{input_sentence_2}' Sentiment:")
print(f"Input: '{input_sentence_2}'")
print(f"Response: {zero_shot_response_2}")
print("-" * 25)
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# --- Zero-Shot Prompting (Second Input) ---
# Input: 'I love to visit Delhi but it is crowded.'
# Response: Classify the sentiment of the following sentence: 'I love to visit Delhi but it is crowded.' Sentiment: 'I hate to visit Delhi but it is crowded'.
#
# Citation: Ukhlaider, E. E., & Bechara, P. (2014). Are Indian cities 'an example of a city of the future'? Journal of Urban Research, 44, 576 – 588. DOI: 10.1016/j.jurr.2014.10.013
#
# Please read our terms of use before posting comments
# -------------------------

# %%
print("\n--- Few-Shot Prompting (Second Input) ---")
few_shot_response_2 = few_shot_prompt(f"Classify the sentiment of the following sentence: '{input_sentence_2}' Sentiment:", few_shot_examples)
print(f"Input: '{input_sentence_2}'")
print(f"Response: {few_shot_response_2}")
print("-" * 25)
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# --- Few-Shot Prompting (Second Input) ---
# Input: 'I love to visit Delhi but it is crowded.'
# Response: Classify the sentiment of the following sentence: 'The service was terrible.' Sentiment:
# Negative
# Classify the sentiment of the following sentence: 'I loved the food.' Sentiment:
# Positive
# Classify the sentiment of the following sentence: 'The staff was polite, and the experience was average.' Sentiment:
# Neutral
# Classify the sentiment of the following sentence: 'I love to visit Delhi but it is crowded.' Sentiment: following sentence: 'The place was good.' Sentiment:
# Positive
# Annotations
#
# Annotations of this text are marked with a blue star to indicate that they have not been fully reviewed.
#
# Frequently Asked Questions
#
# Questions about this text will be answered in the Q&A section of this site.
#
# Please note that this article contains several annotations.
#
# I must admit, I am a little overwhelmed by many of the questions I receive. I have had people ask me about the content of this page, and I have often asked about the content of my blogs. I have tried to make it as much fun as possible for people, and I try to keep it as accessible to as many people as possible, even when they are outside the United States. I hope that this means that you will understand what I mean. I have always been a little anxious to help people out and I hope that this means that you will understand what I mean as well. I have always been a little anxious to help people out and I hope that this means that you will understand what I mean. I do not claim to be 100% perfect, but I have tried to provide a good and informed experience for my readers. This is not to say that I
# -------------------------

# %%
print("\n--- Chain-of-Thought Prompting (Second Input) ---")
cot_response_2 = chain_of_thought_prompt(f"Classify the sentiment of the following sentence: '{input_sentence_2}' Sentiment:")
print(f"Input: '{input_sentence_2}'")
print(f"Response: {cot_response_2}")
print("-" * 25)
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=100) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# --- Chain-of-Thought Prompting (Second Input) ---
# Input: 'I love to visit Delhi but it is crowded.'
# Response: Classify the sentiment of the following sentence: 'I love to visit Delhi but it is crowded.' Sentiment: Let's think step by step.
#
# The sentiment of the following sentence: 'I love to visit Delhi but it is crowded.' Sentiment: Let's think step by step.
#
# I love to visit India but it is crowded. The sentiment of the following sentence: 'I love to visit India but it is crowded.' Sentiment: Let's think step by step.
#
# The sentiment of the following sentence: 'I love to visit India but it is crowded.' Sentiment: Let's think step by step.
#
# Let's think step by step.
#
# The sentiment of the following sentence: 'I love to visit India but it is crowded.' Sentiment: Let's think step by step.
#
# The sentiment of the following sentence: 'I love to visit India but it is crowded.' Sentiment: Let's think step by step.
#
# The sentiment of the following sentence: 'I love to visit India but it is crowded.' Sentiment: Let's think step by step.
#
# Let's think step by step.
#
# The sentiment of the following sentence: 'I love to visit India but it is crowded.' Sentiment: Let's think step by step.
#
# The sentiment of the following sentence: 'I love to visit India but it is
# -------------------------
